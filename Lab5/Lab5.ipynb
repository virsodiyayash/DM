# %% [markdown]
# # Lab - 4 - Data Preprocessing

# %% [markdown]
# ### 1)  First, you need to read the titanic dataset from local disk and display Last five records

# %%
import pandas as pd

# %%
df = pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# ### 2)  Handle Missing Values in data set [use dropna(), fillna(), and interpolate]

# %%
df.dropna(how="any" , axis=0)
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
newData = df.copy()
newData["Age"] = df["Age"].fillna(value=df["Age"].mean())
newData.isnull().sum()

newData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
newData.fillna({"Cabin" : "Not Available"} , inplace=True)
newData["Cabin"]
# Out:
# 0      Not Available
# 1      Not Available
# 2      Not Available
# 3      Not Available
# 4      Not Available
#            ...
# 886    Not Available
# 887    Not Available
# 888    Not Available
# 889    Not Available
# 890    Not Available
# Name: Cabin, Length: 891, dtype: object

# %%
dataWithInterpolate = df.interpolate()
dataWithInterpolate
# Out:
# C:\Users\virso\AppData\Local\Temp\ipykernel_22480\715769552.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dataWithInterpolate = df.interpolate()
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %% [markdown]
# ### 3)  Apply Scaling to AGE attribute with min max, decimal scaling and z score.

# %%
pureData = df.copy()

# %%
pure_data_2 = df.copy()
age_nm = pure_data_2["Age"]
age_min = age_nm.min()
age_max = age_nm.max()

pure_data_2["MinMaxAge"] = (age_nm - age_max)/(age_max - age_min)
pure_data_2["MinMaxAge"]
# Out:
# 0     -0.728826
# 1     -0.527771
# 2     -0.678562
# 3     -0.565469
# 4     -0.565469
#          ...
# 886   -0.665996
# 887   -0.766524
# 888         NaN
# 889   -0.678562
# 890   -0.603167
# Name: MinMaxAge, Length: 891, dtype: float64

# %%
hello = df.copy()
hello["Age"] = hello["Age"].interpolate()
hello["New Age"] = hello["Age"] / 10 ** len(str(int(hello["Age"].max())))
hello[["Age" , "New Age"]]
# Out:
#       Age  New Age
# 0    22.0    0.220
# 1    38.0    0.380
# 2    26.0    0.260
# 3    35.0    0.350
# 4    35.0    0.350
# ..    ...      ...
# 886  27.0    0.270
# 887  19.0    0.190
# 888  22.5    0.225
# 889  26.0    0.260
# 890  32.0    0.320
#
# [891 rows x 2 columns]

# %%
data_minMax = df.copy()

# %%
age_normal = data_minMax["Age"]
age_mean = age_normal.mean()
age_sd = age_normal.std()
